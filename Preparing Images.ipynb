# %% [markdown]
# ### This is the Fourth Part of Exploratory Data Analysis (EDA) & Processing Data
#
# ### Part 4 ==============================> Downloading & Preparing Images

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import shutil
import requests
from PIL import Image
from io import BytesIO

# %% [markdown]
# # Processing Images

# %% [markdown]
# This function here is used to download all images in the large_product_image column and move it into folder we cretad.
#
# Something to notice that i included a try-catch bloch in the function because some of images (about 6000 = 6K) are corrupted or not found so this would generate error and break the processing.
#
# We could delete those images in the cleaning stage, but i prefer to do it now just for the sake of clarfication.

# %%
# This cell may take some time to finish executing depend of internet and CPU speed
def download(row):
  
  # create filename as follow: Image / asin image / .jpeg
  filename = os.path.join(root_folder, '_'.join([row["asin"]]) + ext)
  
  if filename not in lst:
    os.makedirs(os.path.dirname(filename), exist_ok = True)
    url = row.large_image_url
    
    try:
      # download the image file
      r = requests.get(url, allow_redirects = True)
    
    except:
      pass
    if r:
      with open(filename, 'wb') as f:
        f.write(r.content)
  
root_folder = "Images/"
ext = ".jpeg"

# applying download function
data.apply(download, axis = 1)

# %% [markdown]
# Compress the images folder first and then move to local storage or drive
# so we don't need to download them every time we run this notebook, we have compressed the images first because this is a lot faster in term of moving, as moving one large file is a lot faster than moving 109K small files, the overhead of moving each file is raelly cumbersome.

# %%
# compressing Images folder into Images.7z
# This steps have done using colab 7z compressor
!7z a "Images.7z" "Images/"

# %%
# Moving file from Source to Destination to extract images
# shutil.copy("Source", "Destination")

# Run Extraction here
!7z e Images.7z -o"/content/Images"
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 2927081735 bytes (2792 MiB)
#
# Extracting archive: Images.7z
# --
# Path = Images.7z
# Type = 7z
# Physical Size = 2927081735
# Headers Size = 1281198
# Method = LZMA2:24
# Solid = +
# Blocks = 2
#
# Everything is Ok
#
# Folders: 1
# Files: 109496
# Size:       3274319908
# Compressed: 2927081735

# %%
# Run this cell only if you have donwloaded the images with out cleaning
# And if you wanna done the get image features through tensorflow dataset.

# root_folder = "Images2/"
# removed, filenames = [], []

# for filee in os.listdir(root_folder):
      
#       file_path = os.path.join(root_folder, filee)
#       if filee == 'amazon images':
#         continue
      
#       try:
#         Image.open(file_path)
#         shutil.copy(file_path, "Images")
#         filenames.append(file_path)    
      
#       except:
#         removed.append(filee)
#         os.remove(file_path)

# print("Number of images after removing corrupting images", len(filenames))
# print("Number of removed images", len(removed))

# removed = [i.split('.')[0] for i in removed]
# data = data.loc[~data["asin"].isin(removed)]
# names = [i[-15:-5] for i in filenames]

# %% [markdown]
# Sometimes after exctracting, the images will be inside folder of folder, so i move them into another folder then remove the original one, and also to take their name ( asin ) in our case.

# %%
filenames = []
os.makedirs("Images2")

for i in os.listdir("Images"):
  
  try:
      # the last four characters is the extention
      if i[-4:] == "jpeg":
        shutil.copy("Images/" + i, "Images2/" + i)
        filenames.append("Images/" + i)

      # then rename Images2 to Images and remove Images folder
      shutil.rmtree("Images/")
      os.remove("Images.7z")
  
  except:
    pass
